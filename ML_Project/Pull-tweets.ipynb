# %%
# http://www.tweepy.org/
import sys 
# !{sys.executable} -m pip install tweepy
# !{sys.executable} -m pip install jsonpickle
# !{sys.executable} -m pip install nltk

# %%
# !{sys.executable} -m pip install twitter
# !{sys.executable} -m pip install snscrape
# Out:
# ...
#      |████████████████████████████████| 59 kB 3.1 MB/s eta 0:00:011
# ...

# %%
# !{sys.executable} -m pip install textblob
# !{sys.executable} -m pip install spacy
# Out:
# /bin/bash: {sys.executable}: command not found

# %%
from datetime import date
import datetime
import snscrape.modules.twitter as sntwitter
import pandas as pd
import numpy as np
from textblob import TextBlob
# from wordcloud import WordCloud
import re
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import nltk
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords
# import spacy
# nlp = spacy.load("en_core_web_sm")

# %%
import tweepy
# Authenticate to Twitter
#We are not including here the real tokens used from the Twitter account that pulled the data fro
auth = tweepy.OAuthHandler("consumer_token", 
    "consumer_secret")
auth.set_access_token("key", 
    "Secret")

api = tweepy.API(auth)

try:
    api.verify_credentials()
    print("Authentication OK")
except:
    print("Error during authentication")
# Out:
# Authentication OK

# %%
# Create a list to append tweet data
tweets_list = list()
tweets_temp = pd.DataFrame()
tweets_list2 = pd.DataFrame()
maxTweets = 100

# Using TwitterSearchScraper to scrape data and append tweets to list
# for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:elonmusk').get_items()):
# for n in range(11):
for a in range(30): 
    dd = datetime.date(2019,12,1)
    d = datetime.date(2019,12,1+a)
#     print(d)
    for i,tweet in enumerate(sntwitter.TwitterSearchScraper('$ETH since:'+ str(dd) + ' until:'+ str(d)).get_items()):
        if i>maxTweets:
            break
        tweets_list.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
tweets_list2 = pd.DataFrame(tweets_list)
#     tweets_list2 = pd.concat([tweets_list2,tweets_temp])
    
# Creating a dataframe from the tweets list above
tweets_to_df = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])

# %%
tweets_list2
# Out:
#                              0                    1  \
# 0    2019-12-01 23:59:44+00:00  1201289810771623936
# 1    2019-12-01 23:59:40+00:00  1201289793616928769
# 2    2019-12-01 23:59:33+00:00  1201289765720592384
# 3    2019-12-01 23:58:01+00:00  1201289380658339841
# 4    2019-12-01 23:56:52+00:00  1201289090395787265
# ...                        ...                  ...
# 2924 2019-12-29 22:27:08+00:00  1211413368625598465
# 2925 2019-12-29 22:24:43+00:00  1211412760136843264
# 2926 2019-12-29 22:22:50+00:00  1211412284335120385
# 2927 2019-12-29 22:22:48+00:00  1211412279058673665
# 2928 2019-12-29 22:22:30+00:00  1211412203804545024
#
#                                                       2               3
# 0     @TrevynAW @VitalikButerin @CRHUN7 @LefterisJP ...   arjunbhuptani
# 1     Prices update in $USDT every 1 hour:\n\n$BTC -...   TradeSatoshiP
# 2     Cryptocurrencies $ETH $LTC $DASH $XMR $ZCASH h...  WorldCoinIndex
# ...

# %%
tweets_list2.to_csv('$ETH_tweets2019Dec.csv')
